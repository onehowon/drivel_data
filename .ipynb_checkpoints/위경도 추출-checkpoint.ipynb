# %%
import pandas as pd
import json
import requests
import folium

# %%
places = pd.read_csv('업체정보.csv')

# %%
places
# Out:
#              업체명        업종                                주소            전화번호  \
# 0           강군초밥      초밥,롤             충북 충주시 연원로 28 1층 강군초밥    043-845-3412
# 1            장수골        한식               충북 충주시 대소원면 쇠실로 984    043-846-4189
# 2         원조영덕가든        한식      충북 충주시 노은면 감노로 1595-1 원조영덕가든    043-853-2264
# 3      충주댐198510    카페,디저트                  충북 충주시 충주호수로 586  0507-1456-1985
# 4     비건채식뷔페 빛가람  채식,샐러드뷔페         충북 충주시 신대2길 26 비건채식뷔페 빛가람    043-842-3333
# ...          ...       ...                               ...             ...
# 1583         엘몽끄    카페,디저트   경기 안양시 만안구 병목안로 20 스페이스타워 1층,2층    031-441-7337
# 1584  리얼케익 안양범계점     케이크전문   경기 안양시 동안구 평촌대로227번길 30 1층 리얼케익  0507-1311-8393
# 1585        다정김밥        김밥     경기 안양시 만안구 안양로 316 지하2층 비220호  0507-1364-9868
# 1586    페어리우즈 카페     브런치카페  경기 안양시 동안구 시민대로131번길 10 1층 페어리우즈  0507-1320-4546
# 1587        정호식당        한식         경기 안양시 만안구 안양로343번길 16 1층  0507-1335-9334
#
#                                                     썸네일
# 0     https://search.pstatic.net/common/?autoRotate=...
# 1     https://search.pstatic.net/common/?autoRotate=...
# 2     https://search.pstatic.net/common/?autoRotate=...
# 3     https://search.pstatic.net/common/?autoRotate=...
# 4     https://search.pstatic.net/common/?autoRotate=...
# ...                                                 ...
# 1583  https://search.pstatic.net/common/?autoRotate=...
# 1584  https://search.pstatic.net/common/?autoRotate=...
# 1585  https://search.pstatic.net/common/?autoRotate=...
# 1586  https://search.pstatic.net/common/?autoRotate=...
# 1587  https://search.pstatic.net/common/?autoRotate=...
#
# [1588 rows x 5 columns]

# %%
api_key = '98b6364b112863dd8d4a6d308bac6783'

# %%
def addr_to_lat_lon(addr):
    url = f'https://dapi.kakao.com/v2/local/search/address.json?query={addr}'
    headers = {"Authorization": "KakaoAK " + api_key}
    response = requests.get(url, headers=headers)
    result = json.loads(response.text)
    
    if result['documents']:
        match_first = result['documents'][0]['address']
        if match_first is not None:
            return float(match_first['y']), float(match_first['x'])  # latitude, longitude
    return None, None  # 검색 결과가 없거나 주소가 None인 경우

# %%
# 데이터프레임의 address 열에 함수 적용
places[['latitude', 'longitude']] = places['주소'].apply(lambda x: pd.Series(addr_to_lat_lon(x)))

# %%
places
# Out:
#              업체명        업종                                주소            전화번호  \
# 0           강군초밥      초밥,롤             충북 충주시 연원로 28 1층 강군초밥    043-845-3412
# 1            장수골        한식               충북 충주시 대소원면 쇠실로 984    043-846-4189
# 2         원조영덕가든        한식      충북 충주시 노은면 감노로 1595-1 원조영덕가든    043-853-2264
# 3      충주댐198510    카페,디저트                  충북 충주시 충주호수로 586  0507-1456-1985
# 4     비건채식뷔페 빛가람  채식,샐러드뷔페         충북 충주시 신대2길 26 비건채식뷔페 빛가람    043-842-3333
# ...          ...       ...                               ...             ...
# 1583         엘몽끄    카페,디저트   경기 안양시 만안구 병목안로 20 스페이스타워 1층,2층    031-441-7337
# 1584  리얼케익 안양범계점     케이크전문   경기 안양시 동안구 평촌대로227번길 30 1층 리얼케익  0507-1311-8393
# 1585        다정김밥        김밥     경기 안양시 만안구 안양로 316 지하2층 비220호  0507-1364-9868
# 1586    페어리우즈 카페     브런치카페  경기 안양시 동안구 시민대로131번길 10 1층 페어리우즈  0507-1320-4546
# 1587        정호식당        한식         경기 안양시 만안구 안양로343번길 16 1층  0507-1335-9334
#
#                                                     썸네일   latitude   longitude
# 0     https://search.pstatic.net/common/?autoRotate=...  36.988591  127.930922
# 1     https://search.pstatic.net/common/?autoRotate=...  36.972495  127.820255
# 2     https://search.pstatic.net/common/?autoRotate=...  37.042982  127.774002
# 3     https://search.pstatic.net/common/?autoRotate=...  37.011183  127.978671
# 4     https://search.pstatic.net/common/?autoRotate=...  36.947425  127.898665
# ...                                                 ...        ...         ...
# 1583  https://search.pstatic.net/common/?autoRotate=...  37.398955  126.918372
# 1584  https://search.pstatic.net/common/?autoRotate=...  37.391438  126.953821
# 1585  https://search.pstatic.net/common/?autoRotate=...  37.400531  126.920602
# 1586  https://search.pstatic.net/common/?autoRotate=...  37.388639  126.946557
# 1587  https://search.pstatic.net/common/?autoRotate=...  37.402025  126.917625
#
# [1588 rows x 7 columns]

# %%
null_rows = places[places[['latitude', 'longitude']].isnull().any(axis=1)]

# %%
null_rows
# Out:
#                     업체명       업종  \
# 30             먹보한우 파주점    소고기구이
# 33               내사랑동까스      돈가스
# 45           금성회관 파주야당점  육류,고기요리
# 60     보약정 추어명가 추어탕 돈까스       한식
# 120           수복삼계탕 일산점   백숙,삼계탕
# 221                르빵드비   카페,디저트
# 234            소주물 미사본점  육류,고기요리
# 254   품육참숯소갈비살전문점 화성시청점  육류,고기요리
# 272               옥이떡볶이      떡볶이
# 399          곤드레찜드레 용인점  육류,고기요리
# 405             레이크 106   카페,디저트
# 464                 은미정       한식
# 580               전주는전주       한식
# 643                 해지개   카페,디저트
# 859               카페 시소       카페
# 1086       원조중앙탑막국수 논산점      막국수
# 1103            카페 아트페어   카페,디저트
# 1115         조개대표 삽교직영점     조개요리
# 1133        미광다방 로스터리카페   카페,디저트
# 1153          코홀트커피 1호점      NaN
# 1255          동명닭집 신중동점      닭요리
# 1390        백세삼계탕 수원고색점   백숙,삼계탕
# 1396        야키토리잔잔 인계본점     이자카야
# 1413        포시즌키친 광교직영점       양식
# 1427            스미카츠 본점      돈가스
# 1430              레이크우드   카페,디저트
# 1507            초장집 선부점      생선회
# 1512        포크너 그랑시티자이점   이탈리아음식
# 1515            샘골로 고잔점  육류,고기요리
# 1519            아트스트릿11   카페,디저트
# 1524               파도마루      NaN
# 1579      청록미나리식당 안양범계점       한식
#
#                                                      주소            전화번호  \
# 30                               경기 파주시 지목로 43 101~105호  0507-1362-9955
# 33                                    경기 파주시 송학말길 65 1충    031-945-4800
# 45                        경기 파주시 소리천로 39 117, 118, 119호  0507-1399-2272
# 60    경기 평택시 고덕여염9길 20 101, 102, 103, 104, 107, 108,...  0507-1358-2236
# 120                  경기 고양시 일산동구 장백로 200 114, 115, 116호    031-932-9327
# 221                              경기 하남시 서하남로 436 1,2,3층  0507-1430-1129
# 234                        경기 하남시 미사강변중앙로 181 106, 107호    031-796-0980
# 254                               경기 화성시 남양읍 남양로 617 1충  0507-1422-6890
# 272                                    경기 화성시 목동 393-10  0507-1415-4110
# 399                         경기 용인시 처인구 명지로 31 104, 105호  0507-1394-6777
# 405                     경기 용인시 수지구 호수로106번길 37 1,2층,루프탑  0507-1390-7179
# 464                                 경기 의왕시 벌모루길 1 243-7  0507-1337-9964
# 580                             전북 전주시 완산구 태조로 31 1, 2층  0507-1369-4405
# 643                          제주 제주시 애월읍 애월북서길 52 . 1~2층  0507-1358-8586
# 859                               경기 구리시 한다리길 76 2.3.4층  0507-1492-2119
# 1086                          충남 논산시 연무읍 동안로 1058 1, 2층  0507-1349-1343
# 1103                           충남 논산시 벌곡면 수락로 570 1. 2층  0507-1353-9558
# 1115                          충남 당진시 신평면 삽교천3길 72 1, 2층  0507-1431-8330
# 1133                             충남 당진시 백암로 18 101~103호  0507-1334-0616
# 1153                                                NaN             NaN
# 1255             경기 부천시 원미구 조마루로297번길 31 101, 108, 109호  0507-1354-6936
# 1390                           경기 수원시 권선구 서부로 1533 1~2층  0507-1385-5889
# 1396                        경기 수원시 팔달구 인계로138번길 35 1,2층  0507-1313-0877
# 1413      경기 수원시 영통구 광교호수공원로 277 B2층 249~253, 255 -256호  0507-1322-4378
# 1427                           경기 시흥시 오이도로 237 1,2층 해화로  0507-1362-2467
# 1430                            경기 시흥시 동서로 810 1, 2, 3층  0507-1377-4382
# 1507                     경기 안산시 단원구 선부광장로 27 1, 2층 안산맛집  0507-1391-6685
# 1512                  경기 안산시 상록구 해양1로 199 206, 207호 포크너  0507-1387-4752
# 1515                    경기 안산시 단원구 광덕2로 163-5 112, 113호  0507-1357-4670
# 1519                           경기 안산시 단원구 예술대학로 11 1,2층    031-405-3316
# 1524                                                NaN             NaN
# 1579  경기 안양시 동안구 평촌대로243번길 30 222~225, 242~245, 248 ...  0507-1396-8778
#
#                                                     썸네일  latitude  longitude
# 30    https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 33    https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 45    https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 60    https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 120   https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 221   https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 234   https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 254   https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 272   https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 399   https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 405   https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 464   https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 580   https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 643   https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 859   https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1086  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1103  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1115  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1133  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1153                                                NaN       NaN        NaN
# 1255  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1390  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1396  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1413  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1427  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1430  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1507  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1512  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1515  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1519  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN
# 1524                                                NaN       NaN        NaN
# 1579  https://search.pstatic.net/common/?autoRotate=...       NaN        NaN

# %%
null_rows.isnull().sum()
# Out:
# 업체명           0
# 업종            2
# 주소            2
# 전화번호          2
# 썸네일           2
# latitude     32
# longitude    32
# dtype: int64

# %%
miss_latitude = [37.7264152,37.7067086,37.7163925,37.0391219,37.6525709,37.5216397,37.5625350,37.1949681,37.183310,37.2332457,37.3516282,37.3925207,
                35.8142576,33.4643204,37.5836035,36.1299759,36.1960000,36.8907492,36.8841349,37.9030036,37.4989175, 37.2461035,37.2654128,37.2807338,
                37.3410195,37.3840638,37.3362014,37.2822636,37.3104079,37.3181300,37.2804909,37.3927936]

# %%
miss_longitude = [126.6960509,126.7616044,126.7619732,127.0488304,126.7764242,127.1882042,127.1902085,126.8220652,127.1207578,127.1889302,127.0694440,
                  126.9880719,127.1513311,126.3090018,127.1233685,127.1201792,127.2947570,126.8233683,126.6180931,127.0594271,126.7762668,126.9775483,
                  127.0322937,127.0589033,126.6880130,126.8357619,126.8102084,126.8281717,126.8284574,126.8365824,126.5683656,126.5683797,126.9530641]

# %%
null_rows.loc[:, 'latitude'] = miss_latitude
null_rows.loc[:, 'longitude'] = miss_longitude
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 null_rows.loc[:, 'latitude'] = miss_latitude
#       2 null_rows.loc[:, 'longitude'] = miss_longitude
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:885, in _LocationIndexer.__setitem__(self, key, value)
#     882 self._has_valid_setitem_indexer(key)
#     884 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 885 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1893, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1890 # align and set the values
#    1891 if take_split_path:
#    1892     # We have to operate column-wise
# -> 1893     self._setitem_with_indexer_split_path(indexer, value, name)
#    1894 else:
#    1895     self._setitem_single_block(indexer, value, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1949, in _iLocIndexer._setitem_with_indexer_split_path(self, indexer, value, name)
#    1944     if len(value) == 1 and not is_integer(info_axis):
#    1945         # This is a case like df.iloc[:3, [1]] = [0]
#    1946         #  where we treat as df.iloc[:3, 1] = 0
#    1947         return self._setitem_with_indexer((pi, info_axis[0]), value[0])
# -> 1949     raise ValueError(
#    1950         "Must have equal len keys and value "
#    1951         "when setting with an iterable"
#    1952     )
#    1954 elif lplane_indexer == 0 and len(value) == len(self.obj.index):
#    1955     # We get here in one case via .loc with a all-False mask
#    1956     pass
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
null_rows
# Out:
#      Order              Destination                      Address  \
# 0        1                   미평산림욕장            전라남도 여수시 미평동 21-1
# 1        2                  여수 녹테마레           전라남도 여수시 만성로 (294)
# 12       6                 보령 충청수영성           충청남도 보령시 오천면 충청수영로
# 122      1                   변산해수욕장     전북특별자치도 부안군 변산면 변산로 2076
# 132      2                   바람의 언덕           경상남도 거제시 남부면 도장포마을
# 134      4  거제 학동리 동백나무 숲 및 팔색조 번식지     경상남도 거제시 동부면 거제대로 684-22
# 154      1                     옥계계곡            경상북도 영덕군 달산면 팔각산로
# 167      2                      송악산       제주특별자치도 서귀포시 대정읍 송악관광로
# 238      1                    대방진굴항              경상남도 사천시 굴항길 99
# 254      8                    미시령옛길        강원특별자치도 고성군 토성면 미시령옛길
# 304      3                     섬진강댐  전북특별자치도 임실군 강진면 옥정호로 608-13
# 308      3                  속초등대전망대      강원특별자치도 속초시 영금정로5길 8-28
# 320      3                 서산A지구방조제            충청남도 홍성군 서부면 남당항로
# 324      2            화도푸른물센터 피아노폭포         경기도 남양주시 화도읍 폭포로 562
# 352      4                   동해 해암정         강원특별자치도 동해시 촛대바위길 19
# 365      1      화진포 (강원평화지역 국가지질공원)          강원특별자치도 고성군 거진읍 현내면
# 369      5                      대진항         강원특별자치도 고성군 현내면 대진항길
# 373      9                      대진항         강원특별자치도 고성군 현내면 대진항길
# 374     10      화진포 (강원평화지역 국가지질공원)          강원특별자치도 고성군 거진읍 현내면
# 414      3                   호명호수공원       경기도 가평군 청평면 상천리 산371-2
# 432      2                      대청호          대전광역시 동구 / 충청북도 문의면
#
#                                                    Tag DriveCourseID PlaceID  \
# 0                     #관광지 #산림욕 #숲산책 #여수관광 #여수여행 #전남여행         DC001    P001
# 1           #가볼래터 #문화시설 #미디어아트 #여수 #여수가볼만한곳 #여행구독 #전시관         DC001    P002
# 12   #가족여행 #관광지 #교과서속여행 #동백꽃필무렵 #드라마촬영지 #보령문화재 #보령오...         DC002    P013
# 122  #2024_여행가는달과함께하는_발도장여행지 #가족과함께 #관광지 #문화관광해설사 #...         DC021    P123
# 132  #17_18한국관광100선 #19_20한국관광100선 #2024_여행가는달과함께하는...         DC023    P133
# 134  #가족여행 #거제시동백군락지 #거제팔색조 #거제학동리동백나무숲 #경상권 #관광지 #...         DC023    P135
# 154                  #가족여행 #경상권 #계곡 #관광지 #옥계계곡 #자연 #피서         DC028    P155
# 167  #가족여행 #걷기길 #관광지 #바다풍경 #송악산 #연인과함께 #자연 #제주권 #친구와함께         DC031    P168
# 238  #가족여행 #경치좋은곳 #관광지 #대방진굴항 #사천가볼만한곳 #아이와함께 #역사 #...         DC045    P239
# 254               #강원도여행 #고성관광 #드라이브 #레포츠 #미시령고개 #인제관광         DC047    P255
# 304  #경치여행 #경치좋은곳 #관광지 #교육여행 #댐 #물문화관 #섬진강 #섬진강댐 #아...         DC055    P305
# 308  #가족과함께 #가족여행 #강원권 #경치여행 #경치좋은곳 #관광지 #바다 #바다경치 ...         DC056    P309
# 320      #간월도 #관광지 #서산간척지 #서산방조제 #자연 #조류탐사 #천수만 #철새도래지         DC058    P321
# 324  #가족여행 #경치좋은곳 #관광지 #남양주 #남양주나들이 #남양주놀거리 #남양주몰놀이...         DC059    P325
# 352  #가족여행 #강원권 #강원도유형문화재 #관광지 #북평해암정 #역사 #역사공부 #역사...         DC064    P353
# 365  #가을동화촬영지 #가족여행 #강원권 #관광지 #기차여행 #나들이 #당일치기여행 #데...         DC068    P366
# 369  #가족과함께 #강원권 #경치여행 #경치좋은곳 #관광지 #대진항 #바다 #바다경치 #...         DC068    P370
# 373  #가족과함께 #강원권 #경치여행 #경치좋은곳 #관광지 #대진항 #바다 #바다경치 #...         DC068    P374
# 374  #가을동화촬영지 #가족여행 #강원권 #관광지 #기차여행 #나들이 #당일치기여행 #데...         DC068    P375
# 414  #가족과함께 #가평가볼만한곳 #가평당일치기여행 #가평둘러보기좋은곳 #가평호명호수 #...         DC076    P415
# 432  #2024_여행가는달과함께하는_발도장여행지 #관광지 #산책코스 #산책하기좋은곳 #아...         DC079    P433
#
#       latitude   longitude
# 0    34.764496  127.709803
# 1    34.774560  127.725915
# 12   36.439866  126.522982
# 122  35.681280  126.531507
# 132  34.743942  128.663203
# 134  34.757761  128.641038
# 154  36.329715  129.258906
# 167  33.207744  126.290967
# 238  34.928899  128.056310
# 254  38.218730  128.412771
# 304  35.542285  127.111934
# 308  38.213681  128.599997
# 320  36.603395  126.432551
# 324  37.631634  127.347001
# 352  37.479058  129.159095
# 365  38.482213  128.436079
# 369  38.498853  128.426230
# 373  38.498853  128.426230
# 374  38.482213  128.436079
# 414  37.777299  127.454241
# 432  36.479282  127.484534

# %%
for i in range(len(places)):
    if places['PlaceID'][i] in null_rows['PlaceID'].values:
        places.loc[i, ['latitude', 'longitude']] = null_rows[null_rows['PlaceID'] == places['PlaceID'][i]][['latitude', 'longitude']].values[0]

# %%
places.to_csv('placesfinal.csv', encoding = 'utf-8')
