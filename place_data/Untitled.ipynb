# %%
import pandas as pd

# %%
df = pd.read_csv("Last_korea_tour.csv", encoding='utf-8')

# %%
df
# Out:
#      Unnamed: 0                Title                           Address  \
# 0             0              감로암(서울)               서울특별시 종로구 율곡로23길 16
# 1             1              개운사(서울)                 서울특별시 성북구 개운사길 73
# 2             2              경국사(서울)             서울특별시 성북구 보국문로 113-10
# 3             3      과천서울대공원기린나라키즈체험                 경기도 과천시 대공원광장로 80
# 4             4              관문사(서울)              서울특별시 서초구 바우뫼로7길 111
# ..          ...                  ...                               ...
# 733         733  제주힐링명상센터 (무병장수테마파크)         제주특별자치도 제주시 애월읍 어음13길 196
# 734         734              천왕사(제주)  제주특별자치도 제주시 1100로 2528-111 (노형동)
# 735         735   천지연폭포 (제주도 국가지질공원)                  제주특별자치도 서귀포시 천지동
# 736         736         코코몽에코파크 (제주)          제주특별자치도 서귀포시 남원읍 태위로 536
# 737         737     한라산 (제주도 국가지질공원)         제주특별자치도 제주시 1100로 2070-61
#
#                                             firstimage  \
# 0    http://tong.visitkorea.or.kr/cms/resource/85/2...
# ...

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.to_excel('output.xlsx', index=False)
